# %% [markdown]
# ## Requests

# %%
# %pip install requests
# Out:
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
res = requests.get("https://example.com/")
res
# Out:
# <Response [200]>

# %%
res.status_code
# Out:
# 200

# %%
res.raise_for_status()

# %%
content = res.content
content
# Out:
# b'<!doctype html><html lang="en"><head><title>Example Domain</title><meta name="viewport" content="width=device-width, initial-scale=1"><style>body{background:#eee;width:60vw;margin:15vh auto;font-family:system-ui,sans-serif}h1{font-size:1.5em}div{opacity:0.8}a:link,a:visited{color:#348}</style><body><div><h1>Example Domain</h1><p>This domain is for use in documentation examples without needing permission. Avoid use in operations.<p><a href="https://iana.org/domains/example">Learn more</a></div></body></html>\n'

# %%
content.decode('utf8')
# Out:
# '<!doctype html><html lang="en"><head><title>Example Domain</title><meta name="viewport" content="width=device-width, initial-scale=1"><style>body{background:#eee;width:60vw;margin:15vh auto;font-family:system-ui,sans-serif}h1{font-size:1.5em}div{opacity:0.8}a:link,a:visited{color:#348}</style><body><div><h1>Example Domain</h1><p>This domain is for use in documentation examples without needing permission. Avoid use in operations.<p><a href="https://iana.org/domains/example">Learn more</a></div></body></html>\n'

# %%
text = res.text
text
# Out:
# '<!doctype html><html lang="en"><head><title>Example Domain</title><meta name="viewport" content="width=device-width, initial-scale=1"><style>body{background:#eee;width:60vw;margin:15vh auto;font-family:system-ui,sans-serif}h1{font-size:1.5em}div{opacity:0.8}a:link,a:visited{color:#348}</style><body><div><h1>Example Domain</h1><p>This domain is for use in documentation examples without needing permission. Avoid use in operations.<p><a href="https://iana.org/domains/example">Learn more</a></div></body></html>\n'

# %%
response = requests.get('https://api.github.com')
text = response.text
text
# Out:
# '{\n  "current_user_url": "https://api.github.com/user",\n  "current_user_authorizations_html_url": "https://github.com/settings/connections/applications{/client_id}",\n  "authorizations_url": "https://api.github.com/authorizations",\n  "code_search_url": "https://api.github.com/search/code?q={query}{&page,per_page,sort,order}",\n  "commit_search_url": "https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}",\n  "emails_url": "https://api.github.com/user/emails",\n  "emojis_url": "https://api.github.com/emojis",\n  "events_url": "https://api.github.com/events",\n  "feeds_url": "https://api.github.com/feeds",\n  "followers_url": "https://api.github.com/user/followers",\n  "following_url": "https://api.github.com/user/following{/target}",\n  "gists_url": "https://api.github.com/gists{/gist_id}",\n  "hub_url": "https://api.github.com/hub",\n  "issue_search_url": "https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}",\n  "issues_url": "https://api.github.com/issues",\n  "keys_url": "https://api.github.com/user/keys",\n  "label_search_url": "https://api.github.com/search/labels?q={query}&repository_id={repository_id}{&page,per_page}",\n  "notifications_url": "https://api.github.com/notifications",\n  "organization_url": "https://api.github.com/orgs/{org}",\n  "organization_repositories_url": "https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}",\n  "organization_teams_url": "https://api.github.com/orgs/{org}/teams",\n  "public_gists_url": "https://api.github.com/gists/public",\n  "rate_limit_url": "https://api.github.com/rate_limit",\n  "repository_url": "https://api.github.com/repos/{owner}/{repo}",\n  "repository_search_url": "https://api.github.com/search/repositories?q={query}{&page,per_page,sort,order}",\n  "current_user_repositories_url": "https://api.github.com/user/repos{?type,page,per_page,sort}",\n  "starred_url": "https://api.github.com/user/starred{/owner}{/repo}",\n  "starred_gists_url": "https://api.github.com/gists/starred",\n  "topic_search_url": "https://api.github.com/search/topics?q={query}{&page,per_page}",\n  "user_url": "https://api.github.com/users/{user}",\n  "user_organizations_url": "https://api.github.com/user/orgs",\n  "user_repositories_url": "https://api.github.com/users/{user}/repos{?type,page,per_page,sort}",\n  "user_search_url": "https://api.github.com/search/users?q={query}{&page,per_page,sort,order}"\n}\n'

# %%
import json

info = json.loads(text)
info
# Out:
# {'current_user_url': 'https://api.github.com/user',
#  'current_user_authorizations_html_url': 'https://github.com/settings/connections/applications{/client_id}',
#  'authorizations_url': 'https://api.github.com/authorizations',
#  'code_search_url': 'https://api.github.com/search/code?q={query}{&page,per_page,sort,order}',
#  'commit_search_url': 'https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}',
#  'emails_url': 'https://api.github.com/user/emails',
#  'emojis_url': 'https://api.github.com/emojis',
#  'events_url': 'https://api.github.com/events',
#  'feeds_url': 'https://api.github.com/feeds',
#  'followers_url': 'https://api.github.com/user/followers',
#  'following_url': 'https://api.github.com/user/following{/target}',
#  'gists_url': 'https://api.github.com/gists{/gist_id}',
#  'hub_url': 'https://api.github.com/hub',
#  'issue_search_url': 'https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}',
#  'issues_url': 'https://api.github.com/issues',
#  'keys_url': 'https://api.github.com/user/keys',
#  'label_search_url': 'https://api.github.com/search/labels?q={query}&repository_id={repository_id}{&page,per_page}',
#  'notifications_url': 'https://api.github.com/notifications',
#  'organization_url': 'https://api.github.com/orgs/{org}',
#  'organization_repositories_url': 'https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}',
#  'organization_teams_url': 'https://api.github.com/orgs/{org}/teams',
#  'public_gists_url': 'https://api.github.com/gists/public',
#  'rate_limit_url': 'https://api.github.com/rate_limit',
#  'repository_url': 'https://api.github.com/repos/{owner}/{repo}',
#  'repository_search_url': 'https://api.github.com/search/repositories?q={query}{&page,per_page,sort,order}',
#  'current_user_repositories_url': 'https://api.github.com/user/repos{?type,page,per_page,sort}',
#  'starred_url': 'https://api.github.com/user/starred{/owner}{/repo}',
#  'starred_gists_url': 'https://api.github.com/gists/starred',
#  'topic_search_url': 'https://api.github.com/search/topics?q={query}{&page,per_page}',
#  'user_url': 'https://api.github.com/users/{user}',
#  'user_organizations_url': 'https://api.github.com/user/orgs',
#  'user_repositories_url': 'https://api.github.com/users/{user}/repos{?type,page,per_page,sort}',
#  'user_search_url': 'https://api.github.com/search/users?q={query}{&page,per_page,sort,order}'}

# %%
response.json()
# Out:
# {'current_user_url': 'https://api.github.com/user',
#  'current_user_authorizations_html_url': 'https://github.com/settings/connections/applications{/client_id}',
#  'authorizations_url': 'https://api.github.com/authorizations',
#  'code_search_url': 'https://api.github.com/search/code?q={query}{&page,per_page,sort,order}',
#  'commit_search_url': 'https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}',
#  'emails_url': 'https://api.github.com/user/emails',
#  'emojis_url': 'https://api.github.com/emojis',
#  'events_url': 'https://api.github.com/events',
#  'feeds_url': 'https://api.github.com/feeds',
#  'followers_url': 'https://api.github.com/user/followers',
#  'following_url': 'https://api.github.com/user/following{/target}',
#  'gists_url': 'https://api.github.com/gists{/gist_id}',
#  'hub_url': 'https://api.github.com/hub',
#  'issue_search_url': 'https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}',
#  'issues_url': 'https://api.github.com/issues',
#  'keys_url': 'https://api.github.com/user/keys',
#  'label_search_url': 'https://api.github.com/search/labels?q={query}&repository_id={repository_id}{&page,per_page}',
#  'notifications_url': 'https://api.github.com/notifications',
#  'organization_url': 'https://api.github.com/orgs/{org}',
#  'organization_repositories_url': 'https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}',
#  'organization_teams_url': 'https://api.github.com/orgs/{org}/teams',
#  'public_gists_url': 'https://api.github.com/gists/public',
#  'rate_limit_url': 'https://api.github.com/rate_limit',
#  'repository_url': 'https://api.github.com/repos/{owner}/{repo}',
#  'repository_search_url': 'https://api.github.com/search/repositories?q={query}{&page,per_page,sort,order}',
#  'current_user_repositories_url': 'https://api.github.com/user/repos{?type,page,per_page,sort}',
#  'starred_url': 'https://api.github.com/user/starred{/owner}{/repo}',
#  'starred_gists_url': 'https://api.github.com/gists/starred',
#  'topic_search_url': 'https://api.github.com/search/topics?q={query}{&page,per_page}',
#  'user_url': 'https://api.github.com/users/{user}',
#  'user_organizations_url': 'https://api.github.com/user/orgs',
#  'user_repositories_url': 'https://api.github.com/users/{user}/repos{?type,page,per_page,sort}',
#  'user_search_url': 'https://api.github.com/search/users?q={query}{&page,per_page,sort,order}'}

# %%
response.headers
# Out:
# {'Date': 'Wed, 28 Jan 2026 16:17:34 GMT', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept,Accept-Encoding, Accept, X-Requested-With', 'ETag': '"4f825cc84e1c733059d46e76e6df9db557ae5254f9625dfe8e1b09499c449438"', 'x-github-api-version-selected': '2022-11-28', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Server': 'github.com', 'Content-Type': 'application/json; charset=utf-8', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Content-Encoding': 'gzip', 'Accept-Ranges': 'bytes', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '58', 'X-RateLimit-Reset': '1769620633', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '2', 'Content-Length': '530', 'X-GitHub-Request-Id': '5676:28ADFF:1408FB0:11E9D15:697A36A5'}

# %%
res.headers
# Out:
# {'Date': 'Wed, 28 Jan 2026 15:54:53 GMT', 'Content-Type': 'text/html', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Content-Encoding': 'gzip', 'last-modified': 'Tue, 27 Jan 2026 13:22:54 GMT', 'allow': 'GET, HEAD', 'Age': '2261', 'cf-cache-status': 'HIT', 'Vary': 'Accept-Encoding', 'Server': 'cloudflare', 'CF-RAY': '9c51abc25c7de856-FRA'}

# %%
response.headers['Content-Type']
# Out:
# 'application/json; charset=utf-8'

# %%
res = requests.get('https://api.github.com/search/repositories?q=requests+language:python')
res.text
# Out:
# '{"total_count":47083,"incomplete_results":false,"items":[{"id":1362490,"node_id":"MDEwOlJlcG9zaXRvcnkxMzYyNDkw","name":"requests","full_name":"psf/requests","private":false,"owner":{"login":"psf","id":50630501,"node_id":"MDEyOk9yZ2FuaXphdGlvbjUwNjMwNTAx","avatar_url":"https://avatars.githubusercontent.com/u/50630501?v=4","gravatar_id":"","url":"https://api.github.com/users/psf","html_url":"https://github.com/psf","followers_url":"https://api.github.com/users/psf/followers","following_url":"https://api.github.com/users/psf/following{/other_user}","gists_url":"https://api.github.com/users/psf/gists{/gist_id}","starred_url":"https://api.github.com/users/psf/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/psf/subscriptions","organizations_url":"https://api.github.com/users/psf/orgs","repos_url":"https://api.github.com/users/psf/repos","events_url":"https://api.github.com/users/psf/events{/privacy}","received_events_url":"https://api.github.com/users/psf/received_events","type":"Organization","user_view_type":"public","site_admin":false},"html_url":"https://github.com/psf/requests","description":"A simple, yet elegant, HTTP library.","fork":false,"url":"https://api.github.com/repos/psf/requests","forks_url":"https://api.github.com/repos/psf/requests/forks","keys_url":"https://api.github.com/repos/psf/requests/keys{/key_id}","collaborators_url":"https://api.github.com/repos/psf/requests/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/psf/requests/teams","hooks_url":"https://api.github.com/repos/psf/requests/hooks","issue_events_url":"https://api.github.com/repos/psf/requests/issues/events{/number}","events_url":"https://api.github.com/repos/psf/requests/events","assignees_url":"https://api.github.com/repos/psf/requests/assignees{/user}","branches_url":"https://api.github.com/repos/psf/requests/branches{/branch}","tags_url":"https://api.github.com/repos/psf/requests/tags","blobs_url":"https://api.github.com/repos/psf/requests/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/psf/requests/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/psf/requests/git/refs{/sha}","trees_url":"https://api.github.com/repos/psf/requests/git/trees{/sha}","statuses_url":"https://api.github.com/repos/psf/requests/statuses/{sha}","languages_url":"https://api.github.com/repos/psf/requests/languages","stargazers_url":"https://api.github.com/repos/psf/requests/stargazers","contributors_url":"https://api.github.com/repos/psf/requests/contributors","subscribers_url":"https://api.github.com/repos/psf/requests/subscribers","subscription_url":"https://api.github.com/repos/psf/requests/subscription","commits_url":"https://api.github.com/repos/psf/requests/commits{/sha}","git_commits_url":"https://api.github.com/repos/psf/requests/git/commits{/sha}","comments_url":"https://api.github.com/repos/psf/requests/comments{/number}","issue_comment_url":"https://api.github.com/repos/psf/requests/issues/comments{/number}","contents_url":"https://api.github.com/repos/psf/requests/contents/{+path}","compare_url":"https://api.github.com/repos/psf/requests/compare/{base}...{head}","merges_url":"https://api.github.com/repos/psf/requests/merges","archive_url":"https://api.github.com/repos/psf/requests/{archive_format}{/ref}","downloads_url":"https://api.github.com/repos/psf/requests/downloads","issues_url":"https://api.github.com/repos/psf/requests/issues{/number}","pulls_url":"https://api.github.com/repos/psf/requests/pulls{/number}","milestones_url":"https://api.github.com/repos/psf/requests/milestones{/number}","notifications_url":"https://api.github.com/repos/psf/requests/notifications{?since,all,participating}","labels_url":"https://api.github.com/repos/psf/requests/labels{/name}","releases_url":"https://api.github.com/repos/psf/requests/releases{/id}","deployments_url":"https://api.github.com/repos/psf/requests/deployments","created_at":"2011-02-13T18:38:17Z","updated_at":"2026-01-28T15:03:34Z","pushed ...

# %%
res.json()
# Out:
# {'total_count': 47083,
#  'incomplete_results': False,
#  'items': [{'id': 1362490,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxMzYyNDkw',
#    'name': 'requests',
#    'full_name': 'psf/requests',
#    'private': False,
#    'owner': {'login': 'psf',
#     'id': 50630501,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjUwNjMwNTAx',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/50630501?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/psf',
#     'html_url': 'https://github.com/psf',
#     'followers_url': 'https://api.github.com/users/psf/followers',
#     'following_url': 'https://api.github.com/users/psf/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/psf/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/psf/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/psf/subscriptions',
#     'organizations_url': 'https://api.github.com/users/psf/orgs',
#     'repos_url': 'https://api.github.com/users/psf/repos',
#     'events_url': 'https://api.github.com/users/psf/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/psf/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/psf/requests',
#    'description': 'A simple, yet elegant, HTTP library.',
#    'fork': False,
#    'url': 'https://api.github.com/repos/psf/requests',
#    'forks_url': 'https://api.github.com/repos/psf/requests/forks',
#    'keys_url': 'https://api.github.com/repos/psf/requests/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/psf/requests/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/psf/requests/teams',
#    'hooks_url': 'https://api.github.com/repos/psf/requests/hooks',
#    'issue_events_url': 'https://api.github.com/repos/psf/requests/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/psf/requests/events',
#    'assignees_url': 'https://api.github.com/repos/psf/requests/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/psf/requests/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/psf/requests/tags',
#    'blobs_url': 'https://api.github.com/repos/psf/requests/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/psf/requests/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/psf/requests/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/psf/requests/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/psf/requests/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/psf/requests/languages',
#    'stargazers_url': 'https://api.github.com/repos/psf/requests/stargazers',
#    'contributors_url': 'https://api.github.com/repos/psf/requests/contributors',
#    'subscribers_url': 'https://api.github.com/repos/psf/requests/subscribers',
#    'subscription_url': 'https://api.github.com/repos/psf/requests/subscription',
#    'commits_url': 'https://api.github.com/repos/psf/requests/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/psf/requests/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/psf/requests/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/psf/requests/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/psf/requests/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/psf/requests/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/psf/requests/merges',
#    'archive_url': 'https://api.github.com/repos/psf/requests/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/psf/requests/downloads',
#    'issues_url': 'https://api.github.com/repos/psf/requests/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/psf/requests/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/psf/requests/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/psf/requests/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/psf/requests/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/psf/requests/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/psf/requests/deployments',
#    'created_at': '2011-02-13T18:38:17Z',
#    'updated_at': '2026-01-28T15:03:34Z',
#    'pushed_at': '2025-12-01T18:13:45Z',
#    'git_url': 'git://github.com/psf/requests.git',
#    'ssh_url': 'git@github.com:psf/requests.git',
#    'clone_url': 'https://github.com/psf/requests.git',
#    'svn_url': 'https://github.com/psf/requests',
#    'homepage': 'https://requests.readthedocs.io/en/latest/',
#    'size': 13287,
#    'stargazers_count': 53690,
#    'watchers_count': 53690,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': False,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 9713,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 334,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['client',
#     'cookies',
#     'forhumans',
#     'http',
#     'humans',
#     'python',
#     'python-requests',
#     'requests'],
#    'visibility': 'public',
#    'forks': 9713,
#    'open_issues': 334,
#    'watchers': 53690,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 122775780,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxMjI3NzU3ODA=',
#    'name': 'requests-html',
#    'full_name': 'psf/requests-html',
#    'private': False,
#    'owner': {'login': 'psf',
#     'id': 50630501,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjUwNjMwNTAx',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/50630501?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/psf',
#     'html_url': 'https://github.com/psf',
#     'followers_url': 'https://api.github.com/users/psf/followers',
#     'following_url': 'https://api.github.com/users/psf/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/psf/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/psf/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/psf/subscriptions',
#     'organizations_url': 'https://api.github.com/users/psf/orgs',
#     'repos_url': 'https://api.github.com/users/psf/repos',
#     'events_url': 'https://api.github.com/users/psf/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/psf/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/psf/requests-html',
#    'description': 'Pythonic HTML Parsing for Humans™',
#    'fork': False,
#    'url': 'https://api.github.com/repos/psf/requests-html',
#    'forks_url': 'https://api.github.com/repos/psf/requests-html/forks',
#    'keys_url': 'https://api.github.com/repos/psf/requests-html/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/psf/requests-html/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/psf/requests-html/teams',
#    'hooks_url': 'https://api.github.com/repos/psf/requests-html/hooks',
#    'issue_events_url': 'https://api.github.com/repos/psf/requests-html/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/psf/requests-html/events',
#    'assignees_url': 'https://api.github.com/repos/psf/requests-html/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/psf/requests-html/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/psf/requests-html/tags',
#    'blobs_url': 'https://api.github.com/repos/psf/requests-html/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/psf/requests-html/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/psf/requests-html/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/psf/requests-html/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/psf/requests-html/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/psf/requests-html/languages',
#    'stargazers_url': 'https://api.github.com/repos/psf/requests-html/stargazers',
#    'contributors_url': 'https://api.github.com/repos/psf/requests-html/contributors',
#    'subscribers_url': 'https://api.github.com/repos/psf/requests-html/subscribers',
#    'subscription_url': 'https://api.github.com/repos/psf/requests-html/subscription',
#    'commits_url': 'https://api.github.com/repos/psf/requests-html/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/psf/requests-html/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/psf/requests-html/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/psf/requests-html/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/psf/requests-html/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/psf/requests-html/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/psf/requests-html/merges',
#    'archive_url': 'https://api.github.com/repos/psf/requests-html/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/psf/requests-html/downloads',
#    'issues_url': 'https://api.github.com/repos/psf/requests-html/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/psf/requests-html/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/psf/requests-html/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/psf/requests-html/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/psf/requests-html/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/psf/requests-html/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/psf/requests-html/deployments',
#    'created_at': '2018-02-24T20:11:02Z',
#    'updated_at': '2026-01-27T18:06:43Z',
#    'pushed_at': '2024-04-16T18:50:38Z',
#    'git_url': 'git://github.com/psf/requests-html.git',
#    'ssh_url': 'git@github.com:psf/requests-html.git',
#    'clone_url': 'https://github.com/psf/requests-html.git',
#    'svn_url': 'https://github.com/psf/requests-html',
#    'homepage': 'http://html.python-requests.org',
#    'size': 2981,
#    'stargazers_count': 13877,
#    'watchers_count': 13877,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': True,
#    'has_discussions': False,
#    'forks_count': 999,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 241,
#    'license': {'key': 'mit',
#     'name': 'MIT License',
#     'spdx_id': 'MIT',
#     'url': 'https://api.github.com/licenses/mit',
#     'node_id': 'MDc6TGljZW5zZTEz'},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['beautifulsoup',
#     'css-selectors',
#     'html',
#     'http',
#     'kennethreitz',
#     'lxml',
#     'pyquery',
#     'python',
#     'requests',
#     'scraping'],
#    'visibility': 'public',
#    'forks': 999,
#    'open_issues': 241,
#    'watchers': 13877,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 6825724,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk2ODI1NzI0',
#    'name': 'requests-oauthlib',
#    'full_name': 'requests/requests-oauthlib',
#    'private': False,
#    'owner': {'login': 'requests',
#     'id': 2805331,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI4MDUzMzE=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/2805331?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/requests',
#     'html_url': 'https://github.com/requests',
#     'followers_url': 'https://api.github.com/users/requests/followers',
#     'following_url': 'https://api.github.com/users/requests/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/requests/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/requests/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/requests/subscriptions',
#     'organizations_url': 'https://api.github.com/users/requests/orgs',
#     'repos_url': 'https://api.github.com/users/requests/repos',
#     'events_url': 'https://api.github.com/users/requests/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/requests/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/requests/requests-oauthlib',
#    'description': 'OAuthlib support for Python-Requests!',
#    'fork': False,
#    'url': 'https://api.github.com/repos/requests/requests-oauthlib',
#    'forks_url': 'https://api.github.com/repos/requests/requests-oauthlib/forks',
#    'keys_url': 'https://api.github.com/repos/requests/requests-oauthlib/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/requests/requests-oauthlib/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/requests/requests-oauthlib/teams',
#    'hooks_url': 'https://api.github.com/repos/requests/requests-oauthlib/hooks',
#    'issue_events_url': 'https://api.github.com/repos/requests/requests-oauthlib/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/requests/requests-oauthlib/events',
#    'assignees_url': 'https://api.github.com/repos/requests/requests-oauthlib/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/requests/requests-oauthlib/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/requests/requests-oauthlib/tags',
#    'blobs_url': 'https://api.github.com/repos/requests/requests-oauthlib/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/requests/requests-oauthlib/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/requests/requests-oauthlib/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/requests/requests-oauthlib/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/requests/requests-oauthlib/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/requests/requests-oauthlib/languages',
#    'stargazers_url': 'https://api.github.com/repos/requests/requests-oauthlib/stargazers',
#    'contributors_url': 'https://api.github.com/repos/requests/requests-oauthlib/contributors',
#    'subscribers_url': 'https://api.github.com/repos/requests/requests-oauthlib/subscribers',
#    'subscription_url': 'https://api.github.com/repos/requests/requests-oauthlib/subscription',
#    'commits_url': 'https://api.github.com/repos/requests/requests-oauthlib/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/requests/requests-oauthlib/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/requests/requests-oauthlib/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/requests/requests-oauthlib/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/requests/requests-oauthlib/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/requests/requests-oauthlib/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/requests/requests-oauthlib/merges',
#    'archive_url': 'https://api.github.com/repos/requests/requests-oauthlib/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/requests/requests-oauthlib/downloads',
#    'issues_url': 'https://api.github.com/repos/requests/requests-oauthlib/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/requests/requests-oauthlib/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/requests/requests-oauthlib/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/requests/requests-oauthlib/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/requests/requests-oauthlib/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/requests/requests-oauthlib/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/requests/requests-oauthlib/deployments',
#    'created_at': '2012-11-23T10:19:44Z',
#    'updated_at': '2026-01-19T11:57:14Z',
#    'pushed_at': '2025-06-18T06:42:02Z',
#    'git_url': 'git://github.com/requests/requests-oauthlib.git',
#    'ssh_url': 'git@github.com:requests/requests-oauthlib.git',
#    'clone_url': 'https://github.com/requests/requests-oauthlib.git',
#    'svn_url': 'https://github.com/requests/requests-oauthlib',
#    'homepage': 'https://requests-oauthlib.readthedocs.org/',
#    'size': 581,
#    'stargazers_count': 1772,
#    'watchers_count': 1772,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 424,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 125,
#    'license': {'key': 'isc',
#     'name': 'ISC License',
#     'spdx_id': 'ISC',
#     'url': 'https://api.github.com/licenses/isc',
#     'node_id': 'MDc6TGljZW5zZTEw'},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['oauth-client', 'oauth2-client', 'python', 'python-requests'],
#    'visibility': 'public',
#    'forks': 424,
#    'open_issues': 125,
#    'watchers': 1772,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 8930430,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk4OTMwNDMw',
#    'name': 'requests-futures',
#    'full_name': 'ross/requests-futures',
#    'private': False,
#    'owner': {'login': 'ross',
#     'id': 12789,
#     'node_id': 'MDQ6VXNlcjEyNzg5',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/12789?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/ross',
#     'html_url': 'https://github.com/ross',
#     'followers_url': 'https://api.github.com/users/ross/followers',
#     'following_url': 'https://api.github.com/users/ross/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/ross/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/ross/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/ross/subscriptions',
#     'organizations_url': 'https://api.github.com/users/ross/orgs',
#     'repos_url': 'https://api.github.com/users/ross/repos',
#     'events_url': 'https://api.github.com/users/ross/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/ross/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/ross/requests-futures',
#    'description': 'Asynchronous Python HTTP Requests for Humans using Futures',
#    'fork': False,
#    'url': 'https://api.github.com/repos/ross/requests-futures',
#    'forks_url': 'https://api.github.com/repos/ross/requests-futures/forks',
#    'keys_url': 'https://api.github.com/repos/ross/requests-futures/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/ross/requests-futures/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/ross/requests-futures/teams',
#    'hooks_url': 'https://api.github.com/repos/ross/requests-futures/hooks',
#    'issue_events_url': 'https://api.github.com/repos/ross/requests-futures/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/ross/requests-futures/events',
#    'assignees_url': 'https://api.github.com/repos/ross/requests-futures/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/ross/requests-futures/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/ross/requests-futures/tags',
#    'blobs_url': 'https://api.github.com/repos/ross/requests-futures/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/ross/requests-futures/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/ross/requests-futures/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/ross/requests-futures/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/ross/requests-futures/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/ross/requests-futures/languages',
#    'stargazers_url': 'https://api.github.com/repos/ross/requests-futures/stargazers',
#    'contributors_url': 'https://api.github.com/repos/ross/requests-futures/contributors',
#    'subscribers_url': 'https://api.github.com/repos/ross/requests-futures/subscribers',
#    'subscription_url': 'https://api.github.com/repos/ross/requests-futures/subscription',
#    'commits_url': 'https://api.github.com/repos/ross/requests-futures/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/ross/requests-futures/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/ross/requests-futures/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/ross/requests-futures/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/ross/requests-futures/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/ross/requests-futures/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/ross/requests-futures/merges',
#    'archive_url': 'https://api.github.com/repos/ross/requests-futures/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/ross/requests-futures/downloads',
#    'issues_url': 'https://api.github.com/repos/ross/requests-futures/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/ross/requests-futures/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/ross/requests-futures/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/ross/requests-futures/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/ross/requests-futures/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/ross/requests-futures/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/ross/requests-futures/deployments',
#    'created_at': '2013-03-21T14:20:03Z',
#    'updated_at': '2026-01-18T09:29:04Z',
#    'pushed_at': '2026-01-08T22:31:52Z',
#    'git_url': 'git://github.com/ross/requests-futures.git',
#    'ssh_url': 'git@github.com:ross/requests-futures.git',
#    'clone_url': 'https://github.com/ross/requests-futures.git',
#    'svn_url': 'https://github.com/ross/requests-futures',
#    'homepage': None,
#    'size': 206,
#    'stargazers_count': 2229,
#    'watchers_count': 2229,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': False,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 157,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'other',
#     'name': 'Other',
#     'spdx_id': 'NOASSERTION',
#     'url': None,
#     'node_id': 'MDc6TGljZW5zZTA='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 157,
#    'open_issues': 0,
#    'watchers': 2229,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 4290214,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk0MjkwMjE0',
#    'name': 'grequests',
#    'full_name': 'spyoungtech/grequests',
#    'private': False,
#    'owner': {'login': 'spyoungtech',
#     'id': 15212758,
#     'node_id': 'MDQ6VXNlcjE1MjEyNzU4',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/15212758?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/spyoungtech',
#     'html_url': 'https://github.com/spyoungtech',
#     'followers_url': 'https://api.github.com/users/spyoungtech/followers',
#     'following_url': 'https://api.github.com/users/spyoungtech/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/spyoungtech/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/spyoungtech/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/spyoungtech/subscriptions',
#     'organizations_url': 'https://api.github.com/users/spyoungtech/orgs',
#     'repos_url': 'https://api.github.com/users/spyoungtech/repos',
#     'events_url': 'https://api.github.com/users/spyoungtech/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/spyoungtech/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/spyoungtech/grequests',
#    'description': 'Requests + Gevent = <3',
#    'fork': False,
#    'url': 'https://api.github.com/repos/spyoungtech/grequests',
#    'forks_url': 'https://api.github.com/repos/spyoungtech/grequests/forks',
#    'keys_url': 'https://api.github.com/repos/spyoungtech/grequests/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/spyoungtech/grequests/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/spyoungtech/grequests/teams',
#    'hooks_url': 'https://api.github.com/repos/spyoungtech/grequests/hooks',
#    'issue_events_url': 'https://api.github.com/repos/spyoungtech/grequests/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/spyoungtech/grequests/events',
#    'assignees_url': 'https://api.github.com/repos/spyoungtech/grequests/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/spyoungtech/grequests/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/spyoungtech/grequests/tags',
#    'blobs_url': 'https://api.github.com/repos/spyoungtech/grequests/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/spyoungtech/grequests/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/spyoungtech/grequests/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/spyoungtech/grequests/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/spyoungtech/grequests/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/spyoungtech/grequests/languages',
#    'stargazers_url': 'https://api.github.com/repos/spyoungtech/grequests/stargazers',
#    'contributors_url': 'https://api.github.com/repos/spyoungtech/grequests/contributors',
#    'subscribers_url': 'https://api.github.com/repos/spyoungtech/grequests/subscribers',
#    'subscription_url': 'https://api.github.com/repos/spyoungtech/grequests/subscription',
#    'commits_url': 'https://api.github.com/repos/spyoungtech/grequests/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/spyoungtech/grequests/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/spyoungtech/grequests/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/spyoungtech/grequests/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/spyoungtech/grequests/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/spyoungtech/grequests/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/spyoungtech/grequests/merges',
#    'archive_url': 'https://api.github.com/repos/spyoungtech/grequests/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/spyoungtech/grequests/downloads',
#    'issues_url': 'https://api.github.com/repos/spyoungtech/grequests/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/spyoungtech/grequests/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/spyoungtech/grequests/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/spyoungtech/grequests/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/spyoungtech/grequests/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/spyoungtech/grequests/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/spyoungtech/grequests/deployments',
#    'created_at': '2012-05-10T21:50:15Z',
#    'updated_at': '2026-01-26T02:06:30Z',
#    'pushed_at': '2024-08-08T21:52:34Z',
#    'git_url': 'git://github.com/spyoungtech/grequests.git',
#    'ssh_url': 'git@github.com:spyoungtech/grequests.git',
#    'clone_url': 'https://github.com/spyoungtech/grequests.git',
#    'svn_url': 'https://github.com/spyoungtech/grequests',
#    'homepage': 'https://pypi.python.org/pypi/grequests',
#    'size': 62,
#    'stargazers_count': 4586,
#    'watchers_count': 4586,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 330,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 10,
#    'license': {'key': 'bsd-2-clause',
#     'name': 'BSD 2-Clause "Simplified" License',
#     'spdx_id': 'BSD-2-Clause',
#     'url': 'https://api.github.com/licenses/bsd-2-clause',
#     'node_id': 'MDc6TGljZW5zZTQ='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 330,
#    'open_issues': 10,
#    'watchers': 4586,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 2246709,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyMjQ2NzA5',
#    'name': 'robotframework-requests',
#    'full_name': 'MarketSquare/robotframework-requests',
#    'private': False,
#    'owner': {'login': 'MarketSquare',
#     'id': 57290362,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU3MjkwMzYy',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/57290362?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/MarketSquare',
#     'html_url': 'https://github.com/MarketSquare',
#     'followers_url': 'https://api.github.com/users/MarketSquare/followers',
#     'following_url': 'https://api.github.com/users/MarketSquare/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/MarketSquare/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/MarketSquare/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/MarketSquare/subscriptions',
#     'organizations_url': 'https://api.github.com/users/MarketSquare/orgs',
#     'repos_url': 'https://api.github.com/users/MarketSquare/repos',
#     'events_url': 'https://api.github.com/users/MarketSquare/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/MarketSquare/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/MarketSquare/robotframework-requests',
#    'description': 'Robot Framework keyword library wrapper for requests',
#    'fork': False,
#    'url': 'https://api.github.com/repos/MarketSquare/robotframework-requests',
#    'forks_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/forks',
#    'keys_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/teams',
#    'hooks_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/hooks',
#    'issue_events_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/events',
#    'assignees_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/tags',
#    'blobs_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/languages',
#    'stargazers_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/stargazers',
#    'contributors_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/contributors',
#    'subscribers_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/subscribers',
#    'subscription_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/subscription',
#    'commits_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/merges',
#    'archive_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/downloads',
#    'issues_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/MarketSquare/robotframework-requests/deployments',
#    'created_at': '2011-08-22T04:49:19Z',
#    'updated_at': '2026-01-21T06:39:13Z',
#    'pushed_at': '2025-12-17T14:08:01Z',
#    'git_url': 'git://github.com/MarketSquare/robotframework-requests.git',
#    'ssh_url': 'git@github.com:MarketSquare/robotframework-requests.git',
#    'clone_url': 'https://github.com/MarketSquare/robotframework-requests.git',
#    'svn_url': 'https://github.com/MarketSquare/robotframework-requests',
#    'homepage': 'http://marketsquare.github.io/robotframework-requests/',
#    'size': 1296,
#    'stargazers_count': 509,
#    'watchers_count': 509,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': True,
#    'has_discussions': True,
#    'forks_count': 287,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 31,
#    'license': {'key': 'mit',
#     'name': 'MIT License',
#     'spdx_id': 'MIT',
#     'url': 'https://api.github.com/licenses/mit',
#     'node_id': 'MDc6TGljZW5zZTEz'},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['python',
#     'requests',
#     'robot-framework',
#     'robotframework-requests'],
#    'visibility': 'public',
#    'forks': 287,
#    'open_issues': 31,
#    'watchers': 509,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 4006131,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk0MDA2MTMx',
#    'name': 'requests-cache',
#    'full_name': 'requests-cache/requests-cache',
#    'private': False,
#    'owner': {'login': 'requests-cache',
#     'id': 105573137,
#     'node_id': 'O_kgDOBkrrEQ',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/105573137?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/requests-cache',
#     'html_url': 'https://github.com/requests-cache',
#     'followers_url': 'https://api.github.com/users/requests-cache/followers',
#     'following_url': 'https://api.github.com/users/requests-cache/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/requests-cache/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/requests-cache/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/requests-cache/subscriptions',
#     'organizations_url': 'https://api.github.com/users/requests-cache/orgs',
#     'repos_url': 'https://api.github.com/users/requests-cache/repos',
#     'events_url': 'https://api.github.com/users/requests-cache/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/requests-cache/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/requests-cache/requests-cache',
#    'description': 'Persistent HTTP cache for python requests',
#    'fork': False,
#    'url': 'https://api.github.com/repos/requests-cache/requests-cache',
#    'forks_url': 'https://api.github.com/repos/requests-cache/requests-cache/forks',
#    'keys_url': 'https://api.github.com/repos/requests-cache/requests-cache/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/requests-cache/requests-cache/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/requests-cache/requests-cache/teams',
#    'hooks_url': 'https://api.github.com/repos/requests-cache/requests-cache/hooks',
#    'issue_events_url': 'https://api.github.com/repos/requests-cache/requests-cache/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/requests-cache/requests-cache/events',
#    'assignees_url': 'https://api.github.com/repos/requests-cache/requests-cache/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/requests-cache/requests-cache/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/requests-cache/requests-cache/tags',
#    'blobs_url': 'https://api.github.com/repos/requests-cache/requests-cache/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/requests-cache/requests-cache/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/requests-cache/requests-cache/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/requests-cache/requests-cache/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/requests-cache/requests-cache/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/requests-cache/requests-cache/languages',
#    'stargazers_url': 'https://api.github.com/repos/requests-cache/requests-cache/stargazers',
#    'contributors_url': 'https://api.github.com/repos/requests-cache/requests-cache/contributors',
#    'subscribers_url': 'https://api.github.com/repos/requests-cache/requests-cache/subscribers',
#    'subscription_url': 'https://api.github.com/repos/requests-cache/requests-cache/subscription',
#    'commits_url': 'https://api.github.com/repos/requests-cache/requests-cache/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/requests-cache/requests-cache/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/requests-cache/requests-cache/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/requests-cache/requests-cache/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/requests-cache/requests-cache/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/requests-cache/requests-cache/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/requests-cache/requests-cache/merges',
#    'archive_url': 'https://api.github.com/repos/requests-cache/requests-cache/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/requests-cache/requests-cache/downloads',
#    'issues_url': 'https://api.github.com/repos/requests-cache/requests-cache/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/requests-cache/requests-cache/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/requests-cache/requests-cache/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/requests-cache/requests-cache/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/requests-cache/requests-cache/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/requests-cache/requests-cache/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/requests-cache/requests-cache/deployments',
#    'created_at': '2012-04-12T15:25:33Z',
#    'updated_at': '2026-01-22T18:10:49Z',
#    'pushed_at': '2026-01-21T23:00:57Z',
#    'git_url': 'git://github.com/requests-cache/requests-cache.git',
#    'ssh_url': 'git@github.com:requests-cache/requests-cache.git',
#    'clone_url': 'https://github.com/requests-cache/requests-cache.git',
#    'svn_url': 'https://github.com/requests-cache/requests-cache',
#    'homepage': 'https://requests-cache.readthedocs.io',
#    'size': 5416,
#    'stargazers_count': 1477,
#    'watchers_count': 1477,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': True,
#    'forks_count': 156,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 29,
#    'license': {'key': 'bsd-2-clause',
#     'name': 'BSD 2-Clause "Simplified" License',
#     'spdx_id': 'BSD-2-Clause',
#     'url': 'https://api.github.com/licenses/bsd-2-clause',
#     'node_id': 'MDc6TGljZW5zZTQ='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['cache',
#     'dynamodb',
#     'http',
#     'mongodb',
#     'performance',
#     'redis',
#     'requests',
#     'sqlite',
#     'web',
#     'webscraping'],
#    'visibility': 'public',
#    'forks': 156,
#    'open_issues': 29,
#    'watchers': 1477,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 387054552,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzODcwNTQ1NTI=',
#    'name': 'requests-ip-rotator',
#    'full_name': 'Ge0rg3/requests-ip-rotator',
#    'private': False,
#    'owner': {'login': 'Ge0rg3',
#     'id': 16269580,
#     'node_id': 'MDQ6VXNlcjE2MjY5NTgw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/16269580?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/Ge0rg3',
#     'html_url': 'https://github.com/Ge0rg3',
#     'followers_url': 'https://api.github.com/users/Ge0rg3/followers',
#     'following_url': 'https://api.github.com/users/Ge0rg3/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/Ge0rg3/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/Ge0rg3/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/Ge0rg3/subscriptions',
#     'organizations_url': 'https://api.github.com/users/Ge0rg3/orgs',
#     'repos_url': 'https://api.github.com/users/Ge0rg3/repos',
#     'events_url': 'https://api.github.com/users/Ge0rg3/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/Ge0rg3/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/Ge0rg3/requests-ip-rotator',
#    'description': "A Python library to utilize AWS API Gateway's large IP pool as a proxy to generate pseudo-infinite IPs for web scraping and brute forcing.",
#    'fork': False,
#    'url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator',
#    'forks_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/forks',
#    'keys_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/teams',
#    'hooks_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/hooks',
#    'issue_events_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/events',
#    'assignees_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/tags',
#    'blobs_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/languages',
#    'stargazers_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/stargazers',
#    'contributors_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/contributors',
#    'subscribers_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/subscribers',
#    'subscription_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/subscription',
#    'commits_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/merges',
#    'archive_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/downloads',
#    'issues_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/Ge0rg3/requests-ip-rotator/deployments',
#    'created_at': '2021-07-17T23:32:15Z',
#    'updated_at': '2026-01-27T14:25:16Z',
#    'pushed_at': '2025-04-24T21:30:31Z',
#    'git_url': 'git://github.com/Ge0rg3/requests-ip-rotator.git',
#    'ssh_url': 'git@github.com:Ge0rg3/requests-ip-rotator.git',
#    'clone_url': 'https://github.com/Ge0rg3/requests-ip-rotator.git',
#    'svn_url': 'https://github.com/Ge0rg3/requests-ip-rotator',
#    'homepage': 'https://pypi.org/project/requests-ip-rotator/',
#    'size': 52,
#    'stargazers_count': 1640,
#    'watchers_count': 1640,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 173,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 6,
#    'license': {'key': 'gpl-3.0',
#     'name': 'GNU General Public License v3.0',
#     'spdx_id': 'GPL-3.0',
#     'url': 'https://api.github.com/licenses/gpl-3.0',
#     'node_id': 'MDc6TGljZW5zZTk='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['apigateway',
#     'aws',
#     'bugbounty',
#     'bypass',
# ...
#    'branches_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/tags',
#    'blobs_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/languages',
#    'stargazers_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/stargazers',
#    'contributors_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/contributors',
#    'subscribers_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/subscribers',
#    'subscription_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/subscription',
#    'commits_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/merges',
#    'archive_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/downloads',
#    'issues_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/xtekky/TikTok-ViewBot/deployments',
#    'created_at': '2022-07-02T21:24:27Z',
#    'updated_at': '2026-01-23T08:05:42Z',
#    'pushed_at': '2025-02-15T23:39:12Z',
#    'git_url': 'git://github.com/xtekky/TikTok-ViewBot.git',
#    'ssh_url': 'git@github.com:xtekky/TikTok-ViewBot.git',
#    'clone_url': 'https://github.com/xtekky/TikTok-ViewBot.git',
#    'svn_url': 'https://github.com/xtekky/TikTok-ViewBot',
#    'homepage': 'https://t.me/onlpx',
#    'size': 435,
#    'stargazers_count': 1715,
#    'watchers_count': 1715,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 621,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 132,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['bot',
#     'python',
#     'tiktok',
#     'tiktok-api',
#     'tiktok-bot',
#     'tiktok-python',
#     'tiktok-views',
#     'tiktokbot',
#     'views',
#     'zefoy'],
#    'visibility': 'public',
#    'forks': 621,
#    'open_issues': 132,
#    'watchers': 1715,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 1778471,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNzc4NDcx',
#    'name': 'httpbin',
#    'full_name': 'postmanlabs/httpbin',
#    'private': False,
#    'owner': {'login': 'postmanlabs',
#     'id': 10251060,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEwMjUxMDYw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/10251060?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/postmanlabs',
#     'html_url': 'https://github.com/postmanlabs',
#     'followers_url': 'https://api.github.com/users/postmanlabs/followers',
#     'following_url': 'https://api.github.com/users/postmanlabs/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/postmanlabs/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/postmanlabs/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/postmanlabs/subscriptions',
#     'organizations_url': 'https://api.github.com/users/postmanlabs/orgs',
#     'repos_url': 'https://api.github.com/users/postmanlabs/repos',
#     'events_url': 'https://api.github.com/users/postmanlabs/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/postmanlabs/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/postmanlabs/httpbin',
#    'description': 'HTTP Request & Response Service, written in Python + Flask.',
#    'fork': False,
#    'url': 'https://api.github.com/repos/postmanlabs/httpbin',
#    'forks_url': 'https://api.github.com/repos/postmanlabs/httpbin/forks',
#    'keys_url': 'https://api.github.com/repos/postmanlabs/httpbin/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/postmanlabs/httpbin/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/postmanlabs/httpbin/teams',
#    'hooks_url': 'https://api.github.com/repos/postmanlabs/httpbin/hooks',
#    'issue_events_url': 'https://api.github.com/repos/postmanlabs/httpbin/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/postmanlabs/httpbin/events',
#    'assignees_url': 'https://api.github.com/repos/postmanlabs/httpbin/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/postmanlabs/httpbin/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/postmanlabs/httpbin/tags',
#    'blobs_url': 'https://api.github.com/repos/postmanlabs/httpbin/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/postmanlabs/httpbin/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/postmanlabs/httpbin/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/postmanlabs/httpbin/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/postmanlabs/httpbin/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/postmanlabs/httpbin/languages',
#    'stargazers_url': 'https://api.github.com/repos/postmanlabs/httpbin/stargazers',
#    'contributors_url': 'https://api.github.com/repos/postmanlabs/httpbin/contributors',
#    'subscribers_url': 'https://api.github.com/repos/postmanlabs/httpbin/subscribers',
#    'subscription_url': 'https://api.github.com/repos/postmanlabs/httpbin/subscription',
#    'commits_url': 'https://api.github.com/repos/postmanlabs/httpbin/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/postmanlabs/httpbin/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/postmanlabs/httpbin/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/postmanlabs/httpbin/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/postmanlabs/httpbin/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/postmanlabs/httpbin/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/postmanlabs/httpbin/merges',
#    'archive_url': 'https://api.github.com/repos/postmanlabs/httpbin/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/postmanlabs/httpbin/downloads',
#    'issues_url': 'https://api.github.com/repos/postmanlabs/httpbin/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/postmanlabs/httpbin/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/postmanlabs/httpbin/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/postmanlabs/httpbin/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/postmanlabs/httpbin/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/postmanlabs/httpbin/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/postmanlabs/httpbin/deployments',
#    'created_at': '2011-05-20T21:14:01Z',
#    'updated_at': '2026-01-28T15:03:38Z',
#    'pushed_at': '2024-05-24T07:51:48Z',
#    'git_url': 'git://github.com/postmanlabs/httpbin.git',
#    'ssh_url': 'git@github.com:postmanlabs/httpbin.git',
#    'clone_url': 'https://github.com/postmanlabs/httpbin.git',
#    'svn_url': 'https://github.com/postmanlabs/httpbin',
#    'homepage': 'https://httpbin.org',
#    'size': 750,
#    'stargazers_count': 13470,
#    'watchers_count': 13470,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 1909,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 189,
#    'license': {'key': 'isc',
#     'name': 'ISC License',
#     'spdx_id': 'ISC',
#     'url': 'https://api.github.com/licenses/isc',
#     'node_id': 'MDc6TGljZW5zZTEw'},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['api',
#     'http',
#     'http-server',
#     'httpbin',
#     'json',
#     'python',
#     'service',
#     'testing'],
#    'visibility': 'public',
#    'forks': 1909,
#    'open_issues': 189,
#    'watchers': 13470,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 143563911,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNDM1NjM5MTE=',
#    'name': 'proxy_requests',
#    'full_name': 'rootVIII/proxy_requests',
#    'private': False,
#    'owner': {'login': 'rootVIII',
#     'id': 30498791,
#     'node_id': 'MDQ6VXNlcjMwNDk4Nzkx',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/30498791?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/rootVIII',
#     'html_url': 'https://github.com/rootVIII',
#     'followers_url': 'https://api.github.com/users/rootVIII/followers',
#     'following_url': 'https://api.github.com/users/rootVIII/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/rootVIII/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/rootVIII/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/rootVIII/subscriptions',
#     'organizations_url': 'https://api.github.com/users/rootVIII/orgs',
#     'repos_url': 'https://api.github.com/users/rootVIII/repos',
#     'events_url': 'https://api.github.com/users/rootVIII/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/rootVIII/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/rootVIII/proxy_requests',
#    'description': 'a class that uses scraped proxies to make http GET/POST requests (Python requests)',
#    'fork': False,
#    'url': 'https://api.github.com/repos/rootVIII/proxy_requests',
#    'forks_url': 'https://api.github.com/repos/rootVIII/proxy_requests/forks',
#    'keys_url': 'https://api.github.com/repos/rootVIII/proxy_requests/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/rootVIII/proxy_requests/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/rootVIII/proxy_requests/teams',
#    'hooks_url': 'https://api.github.com/repos/rootVIII/proxy_requests/hooks',
#    'issue_events_url': 'https://api.github.com/repos/rootVIII/proxy_requests/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/rootVIII/proxy_requests/events',
#    'assignees_url': 'https://api.github.com/repos/rootVIII/proxy_requests/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/rootVIII/proxy_requests/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/rootVIII/proxy_requests/tags',
#    'blobs_url': 'https://api.github.com/repos/rootVIII/proxy_requests/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/rootVIII/proxy_requests/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/rootVIII/proxy_requests/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/rootVIII/proxy_requests/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/rootVIII/proxy_requests/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/rootVIII/proxy_requests/languages',
#    'stargazers_url': 'https://api.github.com/repos/rootVIII/proxy_requests/stargazers',
#    'contributors_url': 'https://api.github.com/repos/rootVIII/proxy_requests/contributors',
#    'subscribers_url': 'https://api.github.com/repos/rootVIII/proxy_requests/subscribers',
#    'subscription_url': 'https://api.github.com/repos/rootVIII/proxy_requests/subscription',
#    'commits_url': 'https://api.github.com/repos/rootVIII/proxy_requests/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/rootVIII/proxy_requests/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/rootVIII/proxy_requests/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/rootVIII/proxy_requests/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/rootVIII/proxy_requests/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/rootVIII/proxy_requests/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/rootVIII/proxy_requests/merges',
#    'archive_url': 'https://api.github.com/repos/rootVIII/proxy_requests/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/rootVIII/proxy_requests/downloads',
#    'issues_url': 'https://api.github.com/repos/rootVIII/proxy_requests/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/rootVIII/proxy_requests/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/rootVIII/proxy_requests/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/rootVIII/proxy_requests/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/rootVIII/proxy_requests/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/rootVIII/proxy_requests/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/rootVIII/proxy_requests/deployments',
#    'created_at': '2018-08-04T21:23:59Z',
#    'updated_at': '2025-12-29T16:57:51Z',
#    'pushed_at': '2020-12-03T15:41:38Z',
#    'git_url': 'git://github.com/rootVIII/proxy_requests.git',
#    'ssh_url': 'git@github.com:rootVIII/proxy_requests.git',
#    'clone_url': 'https://github.com/rootVIII/proxy_requests.git',
#    'svn_url': 'https://github.com/rootVIII/proxy_requests',
#    'homepage': '',
#    'size': 768,
#    'stargazers_count': 389,
#    'watchers_count': 389,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 43,
#    'mirror_url': None,
#    'archived': True,
#    'disabled': False,
#    'open_issues_count': 2,
#    'license': {'key': 'mit',
#     'name': 'MIT License',
#     'spdx_id': 'MIT',
#     'url': 'https://api.github.com/licenses/mit',
#     'node_id': 'MDc6TGljZW5zZTEz'},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['http',
#     'http-get',
#     'http-getter',
#     'http-proxy',
#     'http-proxy-middleware',
#     'proxy',
#     'proxy-list',
#     'proxy-requests',
#     'proxy-server',
#     'python',
#     'python-requests',
#     'python3',
#     'recursion',
#     'recursion-problem',
#     'requests',
#     'requests-module',
#     'webscraper',
#     'webscraper-api',
#     'webscraping'],
#    'visibility': 'public',
#    'forks': 43,
#    'open_issues': 2,
#    'watchers': 389,
#    'default_branch': 'master',
#    'score': 1.0}]}

# %%
response = requests.get(
    'https://api.github.com/search/repositories',
    params={'q': 'requests+language:python'})

json_response = response.json()
json_response
# Out:
# {'total_count': 309,
#  'incomplete_results': False,
#  'items': [{'id': 972296490,
#    'node_id': 'R_kgDOOfQRKg',
#    'name': 'calendar-mcp',
#    'full_name': 'deciduus/calendar-mcp',
#    'private': False,
#    'owner': {'login': 'deciduus',
#     'id': 151121987,
#     'node_id': 'U_kgDOCQHwQw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/151121987?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/deciduus',
#     'html_url': 'https://github.com/deciduus',
#     'followers_url': 'https://api.github.com/users/deciduus/followers',
#     'following_url': 'https://api.github.com/users/deciduus/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/deciduus/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/deciduus/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/deciduus/subscriptions',
#     'organizations_url': 'https://api.github.com/users/deciduus/orgs',
#     'repos_url': 'https://api.github.com/users/deciduus/repos',
#     'events_url': 'https://api.github.com/users/deciduus/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/deciduus/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/deciduus/calendar-mcp',
#    'description': 'This project implements a Python-based MCP (Model Context Protocol) server that acts as an interface between Large Language Models (LLMs) and the Google Calendar API. It enables LLMs to perform calendar operations via natural language requests.',
#    'fork': False,
#    'url': 'https://api.github.com/repos/deciduus/calendar-mcp',
#    'forks_url': 'https://api.github.com/repos/deciduus/calendar-mcp/forks',
#    'keys_url': 'https://api.github.com/repos/deciduus/calendar-mcp/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/deciduus/calendar-mcp/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/deciduus/calendar-mcp/teams',
#    'hooks_url': 'https://api.github.com/repos/deciduus/calendar-mcp/hooks',
#    'issue_events_url': 'https://api.github.com/repos/deciduus/calendar-mcp/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/deciduus/calendar-mcp/events',
#    'assignees_url': 'https://api.github.com/repos/deciduus/calendar-mcp/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/deciduus/calendar-mcp/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/deciduus/calendar-mcp/tags',
#    'blobs_url': 'https://api.github.com/repos/deciduus/calendar-mcp/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/deciduus/calendar-mcp/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/deciduus/calendar-mcp/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/deciduus/calendar-mcp/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/deciduus/calendar-mcp/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/deciduus/calendar-mcp/languages',
#    'stargazers_url': 'https://api.github.com/repos/deciduus/calendar-mcp/stargazers',
#    'contributors_url': 'https://api.github.com/repos/deciduus/calendar-mcp/contributors',
#    'subscribers_url': 'https://api.github.com/repos/deciduus/calendar-mcp/subscribers',
#    'subscription_url': 'https://api.github.com/repos/deciduus/calendar-mcp/subscription',
#    'commits_url': 'https://api.github.com/repos/deciduus/calendar-mcp/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/deciduus/calendar-mcp/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/deciduus/calendar-mcp/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/deciduus/calendar-mcp/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/deciduus/calendar-mcp/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/deciduus/calendar-mcp/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/deciduus/calendar-mcp/merges',
#    'archive_url': 'https://api.github.com/repos/deciduus/calendar-mcp/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/deciduus/calendar-mcp/downloads',
#    'issues_url': 'https://api.github.com/repos/deciduus/calendar-mcp/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/deciduus/calendar-mcp/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/deciduus/calendar-mcp/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/deciduus/calendar-mcp/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/deciduus/calendar-mcp/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/deciduus/calendar-mcp/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/deciduus/calendar-mcp/deployments',
#    'created_at': '2025-04-24T21:04:27Z',
#    'updated_at': '2026-01-11T19:26:43Z',
#    'pushed_at': '2025-04-24T21:13:27Z',
#    'git_url': 'git://github.com/deciduus/calendar-mcp.git',
#    'ssh_url': 'git@github.com:deciduus/calendar-mcp.git',
#    'clone_url': 'https://github.com/deciduus/calendar-mcp.git',
#    'svn_url': 'https://github.com/deciduus/calendar-mcp',
#    'homepage': None,
#    'size': 66,
#    'stargazers_count': 24,
#    'watchers_count': 24,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 15,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': {'key': 'other',
#     'name': 'Other',
#     'spdx_id': 'NOASSERTION',
#     'url': None,
#     'node_id': 'MDc6TGljZW5zZTA='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 15,
#    'open_issues': 1,
#    'watchers': 24,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 33210074,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzMzIxMDA3NA==',
#    'name': 'secrules-language-evaluation',
#    'full_name': 'SpiderLabs/secrules-language-evaluation',
#    'private': False,
#    'owner': {'login': 'SpiderLabs',
#     'id': 508521,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjUwODUyMQ==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/508521?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/SpiderLabs',
#     'html_url': 'https://github.com/SpiderLabs',
#     'followers_url': 'https://api.github.com/users/SpiderLabs/followers',
#     'following_url': 'https://api.github.com/users/SpiderLabs/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/SpiderLabs/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/SpiderLabs/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/SpiderLabs/subscriptions',
#     'organizations_url': 'https://api.github.com/users/SpiderLabs/orgs',
#     'repos_url': 'https://api.github.com/users/SpiderLabs/repos',
#     'events_url': 'https://api.github.com/users/SpiderLabs/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/SpiderLabs/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/SpiderLabs/secrules-language-evaluation',
#    'description': 'Set of Python scripts to perform SecRules language evaluation on a given http request.',
#    'fork': False,
#    'url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation',
#    'forks_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/forks',
#    'keys_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/teams',
#    'hooks_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/hooks',
#    'issue_events_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/events',
#    'assignees_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/tags',
#    'blobs_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/languages',
#    'stargazers_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/stargazers',
#    'contributors_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/contributors',
#    'subscribers_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/subscribers',
#    'subscription_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/subscription',
#    'commits_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/merges',
#    'archive_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/downloads',
#    'issues_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/SpiderLabs/secrules-language-evaluation/deployments',
#    'created_at': '2015-03-31T21:09:32Z',
#    'updated_at': '2025-03-31T00:57:33Z',
#    'pushed_at': '2017-10-16T15:00:41Z',
#    'git_url': 'git://github.com/SpiderLabs/secrules-language-evaluation.git',
#    'ssh_url': 'git@github.com:SpiderLabs/secrules-language-evaluation.git',
#    'clone_url': 'https://github.com/SpiderLabs/secrules-language-evaluation.git',
#    'svn_url': 'https://github.com/SpiderLabs/secrules-language-evaluation',
#    'homepage': None,
#    'size': 30,
#    'stargazers_count': 14,
#    'watchers_count': 14,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 6,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 6,
#    'open_issues': 0,
#    'watchers': 14,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 92913718,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk5MjkxMzcxOA==',
#    'name': 'BotValue-public',
#    'full_name': 'arnauddelaunay/BotValue-public',
#    'private': False,
#    'owner': {'login': 'arnauddelaunay',
#     'id': 9138186,
#     'node_id': 'MDQ6VXNlcjkxMzgxODY=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/9138186?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/arnauddelaunay',
#     'html_url': 'https://github.com/arnauddelaunay',
#     'followers_url': 'https://api.github.com/users/arnauddelaunay/followers',
#     'following_url': 'https://api.github.com/users/arnauddelaunay/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/arnauddelaunay/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/arnauddelaunay/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/arnauddelaunay/subscriptions',
#     'organizations_url': 'https://api.github.com/users/arnauddelaunay/orgs',
#     'repos_url': 'https://api.github.com/users/arnauddelaunay/repos',
#     'events_url': 'https://api.github.com/users/arnauddelaunay/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/arnauddelaunay/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/arnauddelaunay/BotValue-public',
#    'description': 'BotValue is a Python chatbot to translate Natural Language Requests into DB query. This version has an anonymized database of Partners.',
#    'fork': False,
#    'url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public',
#    'forks_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/forks',
#    'keys_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/teams',
#    'hooks_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/hooks',
#    'issue_events_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/events',
#    'assignees_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/tags',
#    'blobs_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/languages',
#    'stargazers_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/stargazers',
#    'contributors_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/contributors',
#    'subscribers_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/subscribers',
#    'subscription_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/subscription',
#    'commits_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/merges',
#    'archive_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/downloads',
#    'issues_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/arnauddelaunay/BotValue-public/deployments',
#    'created_at': '2017-05-31T06:43:38Z',
#    'updated_at': '2023-04-22T16:50:21Z',
#    'pushed_at': '2017-05-31T09:18:20Z',
#    'git_url': 'git://github.com/arnauddelaunay/BotValue-public.git',
#    'ssh_url': 'git@github.com:arnauddelaunay/BotValue-public.git',
#    'clone_url': 'https://github.com/arnauddelaunay/BotValue-public.git',
#    'svn_url': 'https://github.com/arnauddelaunay/BotValue-public',
#    'homepage': None,
#    'size': 287,
#    'stargazers_count': 11,
#    'watchers_count': 11,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 5,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': {'key': 'gpl-3.0',
#     'name': 'GNU General Public License v3.0',
#     'spdx_id': 'GPL-3.0',
#     'url': 'https://api.github.com/licenses/gpl-3.0',
#     'node_id': 'MDc6TGljZW5zZTk='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['chatbot', 'chatterbot', 'python'],
#    'visibility': 'public',
#    'forks': 5,
#    'open_issues': 1,
#    'watchers': 11,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 923730605,
#    'node_id': 'R_kgDONw8CrQ',
#    'name': 'deepseek-ollama',
#    'full_name': 'adv4000/deepseek-ollama',
#    'private': False,
#    'owner': {'login': 'adv4000',
#     'id': 24209377,
#     'node_id': 'MDQ6VXNlcjI0MjA5Mzc3',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/24209377?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/adv4000',
#     'html_url': 'https://github.com/adv4000',
#     'followers_url': 'https://api.github.com/users/adv4000/followers',
#     'following_url': 'https://api.github.com/users/adv4000/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/adv4000/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/adv4000/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/adv4000/subscriptions',
#     'organizations_url': 'https://api.github.com/users/adv4000/orgs',
#     'repos_url': 'https://api.github.com/users/adv4000/repos',
#     'events_url': 'https://api.github.com/users/adv4000/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/adv4000/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/adv4000/deepseek-ollama',
#    'description': 'Python API Requests to work with Ollama Server running Large Language Models',
#    'fork': False,
#    'url': 'https://api.github.com/repos/adv4000/deepseek-ollama',
#    'forks_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/forks',
#    'keys_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/teams',
#    'hooks_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/hooks',
#    'issue_events_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/events',
#    'assignees_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/tags',
#    'blobs_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/languages',
#    'stargazers_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/stargazers',
#    'contributors_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/contributors',
#    'subscribers_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/subscribers',
#    'subscription_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/subscription',
#    'commits_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/merges',
#    'archive_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/downloads',
#    'issues_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/adv4000/deepseek-ollama/deployments',
#    'created_at': '2025-01-28T18:40:33Z',
#    'updated_at': '2025-04-11T09:14:11Z',
#    'pushed_at': '2025-01-28T21:40:18Z',
#    'git_url': 'git://github.com/adv4000/deepseek-ollama.git',
#    'ssh_url': 'git@github.com:adv4000/deepseek-ollama.git',
#    'clone_url': 'https://github.com/adv4000/deepseek-ollama.git',
#    'svn_url': 'https://github.com/adv4000/deepseek-ollama',
#    'homepage': '',
#    'size': 7,
#    'stargazers_count': 4,
#    'watchers_count': 4,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 2,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 2,
#    'open_issues': 0,
#    'watchers': 4,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 231750274,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyMzE3NTAyNzQ=',
#    'name': 'facebrute',
#    'full_name': 'AntonioMiguel000012/facebrute',
#    'private': False,
#    'owner': {'login': 'AntonioMiguel000012',
#     'id': 59436636,
#     'node_id': 'MDQ6VXNlcjU5NDM2NjM2',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/59436636?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/AntonioMiguel000012',
#     'html_url': 'https://github.com/AntonioMiguel000012',
#     'followers_url': 'https://api.github.com/users/AntonioMiguel000012/followers',
#     'following_url': 'https://api.github.com/users/AntonioMiguel000012/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/AntonioMiguel000012/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/AntonioMiguel000012/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/AntonioMiguel000012/subscriptions',
#     'organizations_url': 'https://api.github.com/users/AntonioMiguel000012/orgs',
#     'repos_url': 'https://api.github.com/users/AntonioMiguel000012/repos',
#     'events_url': 'https://api.github.com/users/AntonioMiguel000012/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/AntonioMiguel000012/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/AntonioMiguel000012/facebrute',
#    'description': 'Facebrute is an advance facebook Bruteforce script made in python language. Just provide username & wordlist and this script is going to try all passwords with returning responses as well. It uses python-requests with tor stem controller that changes its Public IP on every attempt as facebook block IP that try 20 attempts at once.',
#    'fork': False,
#    'url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute',
#    'forks_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/forks',
#    'keys_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/teams',
#    'hooks_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/hooks',
#    'issue_events_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/events',
#    'assignees_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/tags',
#    'blobs_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/languages',
#    'stargazers_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/stargazers',
#    'contributors_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/contributors',
#    'subscribers_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/subscribers',
#    'subscription_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/subscription',
#    'commits_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/merges',
#    'archive_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/downloads',
#    'issues_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/AntonioMiguel000012/facebrute/deployments',
#    'created_at': '2020-01-04T11:15:24Z',
#    'updated_at': '2023-11-26T13:43:56Z',
#    'pushed_at': '2019-11-04T08:43:46Z',
#    'git_url': 'git://github.com/AntonioMiguel000012/facebrute.git',
#    'ssh_url': 'git@github.com:AntonioMiguel000012/facebrute.git',
#    'clone_url': 'https://github.com/AntonioMiguel000012/facebrute.git',
#    'svn_url': 'https://github.com/AntonioMiguel000012/facebrute',
#    'homepage': 'https://github.com/graysuit/facebrute',
#    'size': 80,
#    'stargazers_count': 1,
#    'watchers_count': 1,
#    'language': None,
#    'has_issues': False,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 13,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'gpl-3.0',
#     'name': 'GNU General Public License v3.0',
#     'spdx_id': 'GPL-3.0',
#     'url': 'https://api.github.com/licenses/gpl-3.0',
#     'node_id': 'MDc6TGljZW5zZTk='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 13,
#    'open_issues': 0,
#    'watchers': 1,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 337923098,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzMzc5MjMwOTg=',
#    'name': 'Python-Basic-programs',
#    'full_name': 'sanusanth/Python-Basic-programs',
#    'private': False,
#    'owner': {'login': 'sanusanth',
#     'id': 66163152,
#     'node_id': 'MDQ6VXNlcjY2MTYzMTUy',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/66163152?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/sanusanth',
#     'html_url': 'https://github.com/sanusanth',
#     'followers_url': 'https://api.github.com/users/sanusanth/followers',
#     'following_url': 'https://api.github.com/users/sanusanth/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/sanusanth/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/sanusanth/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/sanusanth/subscriptions',
#     'organizations_url': 'https://api.github.com/users/sanusanth/orgs',
#     'repos_url': 'https://api.github.com/users/sanusanth/repos',
#     'events_url': 'https://api.github.com/users/sanusanth/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/sanusanth/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/sanusanth/Python-Basic-programs',
#    'description': "What is Python? Executive Summary Python is an interpreted, object-oriented, high-level programming language with dynamic semantics. Its high-level built in data structures, combined with dynamic typing and dynamic binding, make it very attractive for Rapid Application Development, as well as for use as a scripting or glue language to connect existing components together. Python's simple, easy to learn syntax emphasizes readability and therefore reduces the cost of program maintenance. Python supports modules and packages, which encourages program modularity and code reuse. The Python interpreter and the extensive standard library are available in source or binary form without charge for all major platforms, and can be freely distributed.   Often, programmers fall in love with Python because of the increased productivity it provides. Since there is no compilation step, the edit-test-debug cycle is incredibly fast. Debugging Python programs is easy: a bug or bad input will never cause a segmentation fault. Instead, when the interpreter discovers an error, it raises an exception. When the program doesn't catch the exception, the interpreter prints a stack trace. A source level debugger allows inspection of local and global variables, evaluation of arbitrary expressions, setting breakpoints, stepping through the code a line at a time, and so on. The debugger is written in Python itself, testifying to Python's introspective power. On the other hand, often the quickest way to debug a program is to add a few print statements to the source: the fast edit-test-debug cycle makes this simple approach very effective.  What is Python? Python is a popular programming language. It was created by Guido van Rossum, and released in 1991.  It is used for:  web development (server-side), software development, mathematics, system scripting.  What can Python do?  Python can be used on a server to create web applications. Python can be used alongside software to create workflows. Python can connect to database systems. It can also read and modify files. Python can be used to handle big data and perform complex mathematics. Python can be used for rapid prototyping, or for production-ready software development.  Why Python?  Python works on different platforms (Windows, Mac, Linux, Raspberry Pi, etc). Python has a simple syntax similar to the English language. Python has syntax that allows developers to write programs with fewer lines than some other programming languages. Python runs on an interpreter system, meaning that code can be executed as soon as it is written. This means that prototyping can be very quick. Python can be treated in a procedural way, an object-oriented way or a functional way.  Good to know  The most recent major version of Python is Python 3, which we shall be using in this tutorial. However, Python 2, although not being updated with anything other than security updates, is still quite popular. In this tutorial Python will be written in a text editor. It is possible to write Python in an Integrated Development Environment, such as Thonny, Pycharm, Netbeans or Eclipse which are particularly useful when managing larger collections of Python files.  Python Syntax compared to other programming languages  Python was designed for readability, and has some similarities to the English language with influence from mathematics. Python uses new lines to complete a command, as opposed to other programming languages which often use semicolons or parentheses. Python relies on indentation, using whitespace, to define scope; such as the scope of loops, functions and classes. Other programming languages often use curly-brackets for this purpose.  Applications for Python  Python is used in many application domains. Here's a sampling.  The Python Package Index lists thousands of third party modules for Python.  Web and Internet Development  Python offers many choices for web development:  Frameworks such as Django and Pyramid ...
#    'fork': False,
#    'url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs',
#    'forks_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/forks',
#    'keys_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/teams',
#    'hooks_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/hooks',
#    'issue_events_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/events',
#    'assignees_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/tags',
#    'blobs_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/languages',
#    'stargazers_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/stargazers',
#    'contributors_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/contributors',
#    'subscribers_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/subscribers',
#    'subscription_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/subscription',
#    'commits_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/merges',
#    'archive_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/downloads',
#    'issues_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/deployments',
#    'created_at': '2021-02-11T03:50:51Z',
#    'updated_at': '2026-01-25T11:32:17Z',
#    'pushed_at': '2023-02-15T17:37:02Z',
#    'git_url': 'git://github.com/sanusanth/Python-Basic-programs.git',
#    'ssh_url': 'git@github.com:sanusanth/Python-Basic-programs.git',
#    'clone_url': 'https://github.com/sanusanth/Python-Basic-programs.git',
#    'svn_url': 'https://github.com/sanusanth/Python-Basic-programs',
#    'homepage': None,
#    'size': 731,
#    'stargazers_count': 88,
#    'watchers_count': 88,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 22,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 22,
#    'open_issues': 1,
#    'watchers': 88,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 422081155,
#    'node_id': 'R_kgDOGShygw',
#    'name': 'Scraping-Data',
#    'full_name': 'NGO-Xuan/Scraping-Data',
#    'private': False,
#    'owner': {'login': 'NGO-Xuan',
#     'id': 33191840,
#     'node_id': 'MDQ6VXNlcjMzMTkxODQw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/33191840?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/NGO-Xuan',
#     'html_url': 'https://github.com/NGO-Xuan',
#     'followers_url': 'https://api.github.com/users/NGO-Xuan/followers',
#     'following_url': 'https://api.github.com/users/NGO-Xuan/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/NGO-Xuan/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/NGO-Xuan/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/NGO-Xuan/subscriptions',
#     'organizations_url': 'https://api.github.com/users/NGO-Xuan/orgs',
#     'repos_url': 'https://api.github.com/users/NGO-Xuan/repos',
#     'events_url': 'https://api.github.com/users/NGO-Xuan/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/NGO-Xuan/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/NGO-Xuan/Scraping-Data',
#    'description': 'In this article, we will scrap data from Zillow.com using the Python programing language. There are several libraries that can help us to do this but today we will start with request and Beautiful Soup.',
#    'fork': False,
#    'url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data',
#    'forks_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/forks',
#    'keys_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/teams',
#    'hooks_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/hooks',
#    'issue_events_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/events',
#    'assignees_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/tags',
#    'blobs_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/languages',
#    'stargazers_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/stargazers',
#    'contributors_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/contributors',
#    'subscribers_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/subscribers',
#    'subscription_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/subscription',
#    'commits_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/merges',
#    'archive_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/downloads',
#    'issues_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/NGO-Xuan/Scraping-Data/deployments',
#    'created_at': '2021-10-28T05:52:01Z',
#    'updated_at': '2024-08-13T21:37:49Z',
#    'pushed_at': '2022-12-13T02:28:04Z',
#    'git_url': 'git://github.com/NGO-Xuan/Scraping-Data.git',
#    'ssh_url': 'git@github.com:NGO-Xuan/Scraping-Data.git',
#    'clone_url': 'https://github.com/NGO-Xuan/Scraping-Data.git',
#    'svn_url': 'https://github.com/NGO-Xuan/Scraping-Data',
#    'homepage': None,
#    'size': 176,
#    'stargazers_count': 5,
#    'watchers_count': 5,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 6,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 6,
#    'open_issues': 1,
#    'watchers': 5,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 1017887083,
#    'node_id': 'R_kgDOPKu5aw',
#    'name': 'mcp-xray',
#    'full_name': 'tivaliy/mcp-xray',
#    'private': False,
#    'owner': {'login': 'tivaliy',
#     'id': 12431595,
#     'node_id': 'MDQ6VXNlcjEyNDMxNTk1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/12431595?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/tivaliy',
#     'html_url': 'https://github.com/tivaliy',
#     'followers_url': 'https://api.github.com/users/tivaliy/followers',
#     'following_url': 'https://api.github.com/users/tivaliy/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/tivaliy/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/tivaliy/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/tivaliy/subscriptions',
#     'organizations_url': 'https://api.github.com/users/tivaliy/orgs',
#     'repos_url': 'https://api.github.com/users/tivaliy/repos',
#     'events_url': 'https://api.github.com/users/tivaliy/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/tivaliy/received_events',
#     'type': 'User',
# ...
#    'stargazers_url': 'https://api.github.com/repos/wkwwa/deepseek-ollama/stargazers',
#    'contributors_url': 'https://api.github.com/repos/wkwwa/deepseek-ollama/contributors',
#    'subscribers_url': 'https://api.github.com/repos/wkwwa/deepseek-ollama/subscribers',
#    'subscription_url': 'https://api.github.com/repos/wkwwa/deepseek-ollama/subscription',
#    'commits_url': 'https://api.github.com/repos/wkwwa/deepseek-ollama/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/wkwwa/deepseek-ollama/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/wkwwa/deepseek-ollama/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/wkwwa/deepseek-ollama/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/wkwwa/deepseek-ollama/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/wkwwa/deepseek-ollama/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/wkwwa/deepseek-ollama/merges',
#    'archive_url': 'https://api.github.com/repos/wkwwa/deepseek-ollama/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/wkwwa/deepseek-ollama/downloads',
#    'issues_url': 'https://api.github.com/repos/wkwwa/deepseek-ollama/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/wkwwa/deepseek-ollama/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/wkwwa/deepseek-ollama/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/wkwwa/deepseek-ollama/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/wkwwa/deepseek-ollama/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/wkwwa/deepseek-ollama/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/wkwwa/deepseek-ollama/deployments',
#    'created_at': '2025-02-08T11:16:53Z',
#    'updated_at': '2025-02-08T11:20:52Z',
#    'pushed_at': '2025-02-08T11:20:49Z',
#    'git_url': 'git://github.com/wkwwa/deepseek-ollama.git',
#    'ssh_url': 'git@github.com:wkwwa/deepseek-ollama.git',
#    'clone_url': 'https://github.com/wkwwa/deepseek-ollama.git',
#    'svn_url': 'https://github.com/wkwwa/deepseek-ollama',
#    'homepage': None,
#    'size': 1,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 542220695,
#    'node_id': 'R_kgDOIFGhlw',
#    'name': 'TMDb-API-Project',
#    'full_name': 'PravinTiwari023/TMDb-API-Project',
#    'private': False,
#    'owner': {'login': 'PravinTiwari023',
#     'id': 94825755,
#     'node_id': 'U_kgDOBabtGw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/94825755?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/PravinTiwari023',
#     'html_url': 'https://github.com/PravinTiwari023',
#     'followers_url': 'https://api.github.com/users/PravinTiwari023/followers',
#     'following_url': 'https://api.github.com/users/PravinTiwari023/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/PravinTiwari023/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/PravinTiwari023/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/PravinTiwari023/subscriptions',
#     'organizations_url': 'https://api.github.com/users/PravinTiwari023/orgs',
#     'repos_url': 'https://api.github.com/users/PravinTiwari023/repos',
#     'events_url': 'https://api.github.com/users/PravinTiwari023/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/PravinTiwari023/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/PravinTiwari023/TMDb-API-Project',
#    'description': 'The clear, simple syntax of Python makes it an ideal language to interact with REST APIs, and in typical Python fashion, there’s a library made specifically to provide that functionality: Requests. Python Requests is a powerful tool that provides the simple elegance of Python to make HTTP requests to any API in the world. At Nylas, we built our REST APIs for email, calendar, and contacts on Python, and we process over 500 million API requests a day, so naturally, we depend a ton on the Python Requests library.',
#    'fork': False,
#    'url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project',
#    'forks_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/forks',
#    'keys_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/teams',
#    'hooks_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/hooks',
#    'issue_events_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/events',
#    'assignees_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/tags',
#    'blobs_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/languages',
#    'stargazers_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/stargazers',
#    'contributors_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/contributors',
#    'subscribers_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/subscribers',
#    'subscription_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/subscription',
#    'commits_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/merges',
#    'archive_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/downloads',
#    'issues_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/PravinTiwari023/TMDb-API-Project/deployments',
#    'created_at': '2022-09-27T17:58:00Z',
#    'updated_at': '2022-12-13T17:24:04Z',
#    'pushed_at': '2022-10-13T04:36:35Z',
#    'git_url': 'git://github.com/PravinTiwari023/TMDb-API-Project.git',
#    'ssh_url': 'git@github.com:PravinTiwari023/TMDb-API-Project.git',
#    'clone_url': 'https://github.com/PravinTiwari023/TMDb-API-Project.git',
#    'svn_url': 'https://github.com/PravinTiwari023/TMDb-API-Project',
#    'homepage': None,
#    'size': 36,
#    'stargazers_count': 2,
#    'watchers_count': 2,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'mit',
#     'name': 'MIT License',
#     'spdx_id': 'MIT',
#     'url': 'https://api.github.com/licenses/mit',
#     'node_id': 'MDc6TGljZW5zZTEz'},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 2,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 605535525,
#    'node_id': 'R_kgDOJBe9JQ',
#    'name': 'coin-price-notification-bot',
#    'full_name': 'mrchinhdev/coin-price-notification-bot',
#    'private': False,
#    'owner': {'login': 'mrchinhdev',
#     'id': 125549537,
#     'node_id': 'U_kgDOB3u74Q',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/125549537?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/mrchinhdev',
#     'html_url': 'https://github.com/mrchinhdev',
#     'followers_url': 'https://api.github.com/users/mrchinhdev/followers',
#     'following_url': 'https://api.github.com/users/mrchinhdev/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/mrchinhdev/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/mrchinhdev/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/mrchinhdev/subscriptions',
#     'organizations_url': 'https://api.github.com/users/mrchinhdev/orgs',
#     'repos_url': 'https://api.github.com/users/mrchinhdev/repos',
#     'events_url': 'https://api.github.com/users/mrchinhdev/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/mrchinhdev/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/mrchinhdev/coin-price-notification-bot',
#    'description': 'Use python language with win10toast library and requests to create coin price notification bot',
#    'fork': False,
#    'url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot',
#    'forks_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/forks',
#    'keys_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/teams',
#    'hooks_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/hooks',
#    'issue_events_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/events',
#    'assignees_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/tags',
#    'blobs_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/languages',
#    'stargazers_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/stargazers',
#    'contributors_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/contributors',
#    'subscribers_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/subscribers',
#    'subscription_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/subscription',
#    'commits_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/merges',
#    'archive_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/downloads',
#    'issues_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/mrchinhdev/coin-price-notification-bot/deployments',
#    'created_at': '2023-02-23T11:13:09Z',
#    'updated_at': '2023-02-23T11:15:54Z',
#    'pushed_at': '2023-02-28T16:44:27Z',
#    'git_url': 'git://github.com/mrchinhdev/coin-price-notification-bot.git',
#    'ssh_url': 'git@github.com:mrchinhdev/coin-price-notification-bot.git',
#    'clone_url': 'https://github.com/mrchinhdev/coin-price-notification-bot.git',
#    'svn_url': 'https://github.com/mrchinhdev/coin-price-notification-bot',
#    'homepage': None,
#    'size': 5,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'score': 1.0}]}

# %%
res_post = requests.post('https://httpbin.org/post', data = {'key': 'value'})

# %%
res_post.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.32.5',
#   'X-Amzn-Trace-Id': 'Root=1-697a3b25-368d9a9568a263fb5af5188f'},
#  'json': None,
#  'origin': '95.214.210.169',
#  'url': 'https://httpbin.org/post'}
