# %% [markdown]
# ## Classes

# %%
import math

point1 = (3, 4)
point2 = (15, 9)

# Circle
circle_center = (1, 5)
circle_radius = 5

def distance(p1, p2):
    # Calculate the Euclidean distance between two points.
    return math.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2)

def is_inside_circle(center, radius, point):
    # Check if a point lies within a circle
    return distance(center, point) <= radius

print("Point 1:", point1)
print("Point 2:", point2)
print("Distance between Point 1 and Point 2:", distance(point1, point2))
print("Is Point 1 inside the circle?", is_inside_circle(circle_center, circle_radius, point1))
print("Is Point 2 inside the circle?", is_inside_circle(circle_center, circle_radius, point2))
# Out:
# Point 1: (3, 4)
# Point 2: (15, 9)
# Distance between Point 1 and Point 2: 13.0
# Is Point 1 inside the circle? True
# Is Point 2 inside the circle? False

# %% [markdown]
# Write an application for users to create a bank account, withdraw and deposit money.

# %%
accounts = {}

def create_account(account_number, owner, balance=0):
    # Creates an account with the given details
    accounts[account_number] = {"owner": owner, "balance": balance}

def deposit(account_number, amount):
    # Deposits money into the account
    accounts[account_number]["balance"] += amount

def withdraw(account_number, amount):
    # Wihtdraws money from the account if sufficient balance is available
    if accounts[account_number]["balance"] >= amount:
        accounts[account_number]["balance"] -= amount
        return True
    return False

def balance(account_number):
    # Returns the current balance of the account
    return accounts[account_number]["balance"]

create_account(101, "Alice", 100)
create_account(102, "Bob", 50)


print("Initial balance for Alice", balance(101))
deposit(101, 50)
print("Balance after deposit for Alice", balance(101))
withdraw(101, 120)
print("Balance after withdrawal for Alice", balance(101))
# Out:
# Initial balance for Alice 100
# Balance after deposit for Alice 150
# Balance after withdrawal for Alice 30

# %% [markdown]
# ## Deifining classes

# %%
class Point:
    pass

a = Point()
a.x = 5
a.y = 8

b = Point()
b.x = 3
b.y = 7

def distance(p1: Point, p2: Point):
    # Calculate the Euclidean distance between two points.
    return math.sqrt((p1.x - p2.x)**2 + (p1.y - p2.y)**2)


distance(a, b)
# Out:
# 2.23606797749979

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

a = Point(2, 4)
print(a.x)
# Out:
# 2

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def distance(self, p2: Point):
        return math.sqrt((self.x - p2.x)**2 + (self.y - p2.y)**2)

a = Point(2, 4)
b = Point(5, 7)

a.distance(b)
# Out:
# 4.242640687119285

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def add_5_to_x(self):
        return self.x + 5

a = Point(2, 4)

a.add_5_to_x()
# Out:
# 7

# %%
import math

class Point:
    def __init__(self, x: float, y: float):
        self.x = x
        self.y = y

    def distance_to(self, other_point: Point):
        return math.sqrt((self.x - other_point.x)**2 + (self.y - other_point.y)**2)
    

class Circle:
    def __init__(self, center: Point, radius):
        self.center = center
        self.radius = radius

    def contains(self, point):
        return self.center.distance_to(point) <= self.radius
    

point1 = Point(3, 4)
point2 = Point(6, 8)
circle = Circle((5, 5), 6)

print("Point 1:", (point1.x, point1.y))
print("Point 2:", (point2.x, point2.y))
print("Distance between point 1 and point 2:", point1.distance_to(point2))
print("Is Point 1 inside the circle", circle.contains(point1))
print("Is Point 2 inside the circle", circle.contains(point2))
# Out:
# Point 1: (3, 4)
# Point 2: (6, 8)
# Distance between point 1 and point 2: 5.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 28
#      26 print("Point 2:", (point2.x, point2.y))
#      27 print("Distance between point 1 and point 2:", point1.distance_to(point2))
# ---> 28 print("Is Point 1 inside the circle", circle.contains(point1))
#      29 print("Is Point 2 inside the circle", circle.contains(point2))
#
# Cell In[14], line 18, in Circle.contains(self, point)
#      17 def contains(self, point):
# ---> 18     return self.center.distance_to(point) <= self.radius
#
# AttributeError: 'tuple' object has no attribute 'distance_to'

# %%
class BankAccount:
    def __init__(self, account_number, owner, balance = 0):
        self.account_number = account_number
        self.owner = owner
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount

    def withdraw(self, amount):
        if self.balance >= amount:
            self.balance -= amount
            return True
        return False
    
    def get_balance(self):
        return self.balance
    

alice_account = BankAccount(101, 'Alice', 100)

print("Initial balance for Alice:", alice_account.get_balance())
alice_account.deposit(50)
print("Balance after deposit:", alice_account.get_balance())
alice_account.withdraw(120)
print("Balance after withdrawal:", alice_account.get_balance())
# Out:
# Initial balance for Alice: 100
# Balance after deposit: 150
# Balance after withdrawal: 30

# %%
class Vector2D:
    def __init__(self, x, y):
        self.x = x
        self.y = y

v1 = Vector2D(3, 5)
v2 = Vector2D(3, 5)

if v1 == v2:
    print("Equal")
else:
    print("Inequal")
# Out:
# Inequal

# %% [markdown]
# # Dunder methods

# %%
class Vector2D:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __eq__(self, other):
        print("Executed")
        return self.x == other.x and self.y == other.y
    
    def __add__(self, other):
        new_x = self.x + other.x
        new_y = self.y + other.y
        return Vector2D(new_x, new_y)
    
    def __str__(self):
        return f"Vector(x={self.x}, y={self.y})"


v1 = Vector2D(3, 5)
v2 = Vector2D(1, 3)
v3 = v1 + v2 
print(v3)

if v1 == v2:
    print("Equal")
else:
    print("Inequal")
# Out:
# Vector(x=4, y=8)
# Executed
# Inequal
