# %%
import sqlite3
import pandas as pd

# %%
with sqlite3.connect('data/chinook.db') as connection:
    df_customers = pd.read_sql(
        "select * from customers",
        con=connection
    )

df_customers.head(10)
# Out:
#    CustomerId  FirstName     LastName  \
# 0           1       Luís    Gonçalves
# 1           2     Leonie       Köhler
# 2           3   François     Tremblay
# 3           4      Bjørn       Hansen
# 4           5  František  Wichterlová
# 5           6     Helena         Holý
# 6           7     Astrid       Gruber
# 7           8       Daan      Peeters
# 8           9       Kara      Nielsen
# 9          10    Eduardo      Martins
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                  JetBrains s.r.o.
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# ...

# %%
df_iris = pd.read_json('data/iris.json')
df_iris.head()
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %%
df_iris.shape
# Out:
# (150, 5)

# %%
df_iris.dtypes
# Out:
# sepalLength    float64
# sepalWidth     float64
# petalLength    float64
# petalWidth     float64
# species            str
# dtype: object

# %%
df_iris.columns
# Out:
# Index(['sepalLength', 'sepalWidth', 'petalLength', 'petalWidth', 'species'], dtype='str')

# %%
# !pip install openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]
# ...

# %%
df_titanic = pd.read_excel('data/titanic.xlsx')
df_titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# !pip install pyarrow
# !pip install fastparquet
# Out:
# ...
#   Using cached pyarrow-23.0.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (3.0 kB)
# Using cached pyarrow-23.0.0-cp313-cp313-macosx_12_0_arm64.whl (34.2 MB)
# ...

# %%
userdata = pd.read_parquet('data/userdata.parquet', engine="pyarrow")

# %%
userdata.info
# Out:
# <bound method DataFrame.info of       registration_dttm    id first_name last_name                     email  \
# 0   2016-02-03 07:55:29     1     Amanda    Jordan          ajordan0@com.com
# 1   2016-02-03 17:04:03     2     Albert   Freeman           afreeman1@is.gd
# 2   2016-02-03 01:09:31     3     Evelyn    Morgan   emorgan2@altervista.org
# 3   2016-02-03 00:36:21     4     Denise     Riley          driley3@gmpg.org
# 4   2016-02-03 05:05:31     5     Carlos     Burns  cburns4@miitbeian.gov.cn
# ..                  ...   ...        ...       ...                       ...
# 995 2016-02-03 10:30:59   996     Dennis    Harris      dharrisrn@eepurl.com
# 996 2016-02-03 17:16:53   997     Gloria  Hamilton    ghamiltonro@rambler.ru
# 997 2016-02-03 05:02:20   998      Nancy    Morris         nmorrisrp@ask.com
# 998 2016-02-03 02:41:32   999      Annie   Daniels    adanielsrq@squidoo.com
# 999 2016-02-03 09:52:18  1000      Julie     Meyer       jmeyerrr@flavors.me
#
# ...

# %%
df_movie = pd.read_csv('data/movie.csv')

# %%
df_movie.sample(10)
# Out:
#                 color       director_name  num_critic_for_reviews  duration  \
# 4817  Black and White    Deborah Anderson                    16.0      66.0
# 1520            Color         Mike Newell                    56.0     124.0
# 1080            Color  Stephen Norrington                   184.0     110.0
# 4605            Color        Thomas Lilti                    18.0     102.0
# 2308            Color      Kevin Reynolds                     9.0     107.0
# 1982            Color         Atom Egoyan                    97.0     107.0
# 359             Color         Ben Stiller                   308.0     121.0
# 4309            Color         Larry Clark                    71.0      91.0
# 3122            Color     François Girard                    94.0     130.0
# 2833            Color     Patrice Leconte                    61.0     112.0
#
#       director_facebook_likes  actor_3_facebook_likes     actor_2_name  \
# ...

# %%
df_iris
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
df_iris.columns = [column.lower() for column in df_iris.columns]
df_iris[['sepallength', 'sepalwidth']]
# Out:
#      sepallength  sepalwidth
# 0            5.1         3.5
# 1            4.9         3.0
# 2            4.7         3.2
# 3            4.6         3.1
# 4            5.0         3.6
# ..           ...         ...
# 145          6.7         3.0
# 146          6.3         2.5
# 147          6.5         3.0
# 148          6.2         3.4
# 149          5.9         3.0
#
# [150 rows x 2 columns]

# %%
df_titanic[df_titanic['Age'] > 30]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_titanic['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
userdata[["first_name", 'gender']]
# Out:
#     first_name  gender
# 0       Amanda  Female
# 1       Albert    Male
# 2       Evelyn  Female
# 3       Denise  Female
# 4       Carlos
# ..         ...     ...
# 995     Dennis    Male
# 996     Gloria  Female
# 997      Nancy
# 998      Annie  Female
# 999      Julie  Female
#
# [1000 rows x 2 columns]

# %%
set(userdata['country'])
# Out:
# {'"Bonaire',
#  'Afghanistan',
#  'Aland Islands',
#  'Albania',
#  'Angola',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Azerbaijan',
#  'Bangladesh',
#  'Belarus',
#  'Belgium',
#  'Bermuda',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Brunei',
#  'Bulgaria',
#  'Burkina Faso',
#  'Cameroon',
#  'Canada',
#  'Cape Verde',
#  'Central African Republic',
#  'Chile',
#  'China',
#  'Colombia',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Cyprus',
#  'Czech Republic',
#  'Democratic Republic of the Congo',
#  'Denmark',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Estonia',
#  'Ethiopia',
#  'Faroe Islands',
#  'Finland',
#  'France',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Greece',
#  'Guatemala',
#  'Guinea',
#  'Haiti',
#  'Honduras',
#  'Indonesia',
#  'Iran',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Ivory Coast',
#  'Japan',
#  'Kazakhstan',
#  'Kiribati',
#  'Laos',
#  'Latvia',
#  'Lebanon',
#  'Liberia',
# ...

# %%
len(set(userdata['country']))
# Out:
# 120

# %%
userdata[userdata["country"] == 'Uzbekistan']
# Out:
#       registration_dttm   id first_name last_name               email gender  \
# 775 2016-02-03 07:18:39  776      Craig     Myers  cmyerslj@google.cn   Male
#
#          ip_address                cc     country   birthdate     salary  \
# 775  133.209.184.64  6759194371556839  Uzbekistan  10/28/1973  253657.82
#
#                     title comments
# 775  Help Desk Technician

# %%
filtered = df_movie[df_movie['duration'] > 120]
filtered
# Out:
#                 color        director_name  num_critic_for_reviews  duration  \
# 0               Color        James Cameron                   723.0     178.0
# 1               Color       Gore Verbinski                   302.0     169.0
# 2               Color           Sam Mendes                   602.0     148.0
# 3               Color    Christopher Nolan                   813.0     164.0
# 5               Color       Andrew Stanton                   462.0     132.0
# ...               ...                  ...                     ...       ...
# 4674            Color           Kay Pollak                    34.0     133.0
# 4695  Black and White        D.W. Griffith                    69.0     123.0
# 4767  Black and White           King Vidor                    48.0     151.0
# 4792  Black and White  Carl Theodor Dreyer                    54.0     126.0
# 4893              NaN      Brandon Landers                     NaN     143.0
#
# ...

# %%
filtered['director_facebook_likes'].sort_values(ascending=False)
# Out:
# 96      22000.0
# 97      22000.0
# 3       22000.0
# 66      22000.0
# 1222    22000.0
#          ...
# 3357        NaN
# 3582        NaN
# 3799        NaN
# 4005        NaN
# 4031        NaN
# Name: director_facebook_likes, Length: 1039, dtype: float64

# %%
df_iris
# Out:
#      sepallength  sepalwidth  petallength  petalwidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
df_iris.describe()
# Out:
#        sepallength  sepalwidth  petallength  petalwidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.057333     3.758000    1.199333
# std       0.828066    0.435866     1.765298    0.762238
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %%
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_titanic['Age'].min()
# Out:
# np.float64(0.42)

# %%
df_titanic['Age'].max()
# Out:
# np.float64(80.0)

# %%
df_titanic['Age'].sum()
# Out:
# np.float64(21205.17)

# %%
df_movie[df_movie['director_facebook_likes'] == df_movie['director_facebook_likes'].max()]
# Out:
#       color         director_name  num_critic_for_reviews  duration  \
# 3603  Color  Joseph Gordon-Levitt                   364.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 3603                  23000.0                   694.0  Scarlett Johansson
#
#       actor_1_facebook_likes       gross                genres  ...  \
# 3603                 23000.0  24475193.0  Comedy|Drama|Romance  ...
#
#      num_user_for_reviews language  country  content_rating     budget  \
# 3603                314.0  English      USA               R  3000000.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 3603      2013.0                19000.0        6.6          2.35
#
#      movie_facebook_likes
# 3603                33000
#
# [1 rows x 28 columns]

# %%
df_movie[['duration', 'director_name', 'actor_2_name']].sort_values(by='duration', ascending=False).head(5)
# Out:
#       duration        director_name              actor_2_name
# 1694     511.0                  NaN  Ingvar Eggert Sigurðsson
# 2436     334.0                  NaN      Nora von Waldstätten
# 1487     330.0      Taylor Hackford             Jesse Borrego
# 1134     325.0       Michael Cimino             Sam Waterston
# 3254     300.0  Chatrichalerm Yukol      Chatchai Plengpanich

# %%
df_movie.nlargest(5, 'duration')
# Out:
#       color        director_name  num_critic_for_reviews  duration  \
# 1694  Color                  NaN                    16.0     511.0
# 2436  Color                  NaN                   108.0     334.0
# 1487  Color      Taylor Hackford                    12.0     330.0
# 1134  Color       Michael Cimino                   102.0     325.0
# 3254  Color  Chatrichalerm Yukol                    31.0     300.0
#
#       director_facebook_likes  actor_3_facebook_likes  \
# 1694                      NaN                    51.0
# 2436                      NaN                    30.0
# 1487                    138.0                   672.0
# 1134                    517.0                   678.0
# 3254                      6.0                     6.0
#
#                   actor_2_name  actor_1_facebook_likes      gross  \
# 1694  Ingvar Eggert Sigurðsson                   147.0        NaN
# 2436      Nora von Waldstätten                   897.0   145118.0
# ...

# %%
userdata.isna().sum()
# Out:
# registration_dttm     0
# id                    0
# first_name            0
# last_name             0
# email                 0
# gender                0
# ip_address            0
# cc                    0
# country               0
# birthdate             0
# salary               68
# title                 0
# comments              6
# dtype: int64

# %%
userdata['comments'].isna().fillna(userdata['salary'].mean()).sum()
# Out:
# np.int64(6)

# %%
userdata['salary'].isna().fillna(userdata['salary'].mean()).sum()
# Out:
# np.int64(68)
